# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas
import matplotlib as plotlib

# %% [markdown]
# # TRAIN DATA

# %%
train_path = "../Dataset/train.csv"
train_data = pandas.read_csv(train_path)
train_data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # DEFINE TARGET (PREDICTION)

# %%
target = train_data.SalePrice
target
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %% [markdown]
# # DEFINE FEATURES

# %%
data_columns = train_data.columns.to_list()
# print(data_columns)
features = []
for column in data_columns:
    # print(train_data[column].dtype)
    if train_data[column].dtype != 'object':
        features.append(column)
features
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'MoSold',
#  'YrSold',
#  'SalePrice']

# %%
features_remove = [
    'Id','MiscVal','BedroomAbvGr',
    'KitchenAbvGr','TotRmsAbvGrd','BsmtHalfBath',
    'BsmtFullBath','LowQualFinSF','MasVnrArea',
    'MSSubClass','LotFrontage','YearRemodAdd',
    'BsmtFinSF1','BsmtFinSF2','BsmtUnfSF',
    'GarageYrBlt','WoodDeckSF','OpenPorchSF',
    'EnclosedPorch','3SsnPorch','ScreenPorch',
    'MoSold','SalePrice']
for feat in features_remove:
    features.remove(feat)
features
# Out:
# ['LotArea',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'FullBath',
#  'HalfBath',
#  'Fireplaces',
#  'GarageCars',
#  'GarageArea',
#  'PoolArea',
#  'YrSold']

# %%
house_features = train_data[features]
# house_features = train_data['Rooms', 'Bathroom', 'Landsize', 'BuildingArea', 
#                         'YearBuilt', 'Lattitude', 'Longtitude']
house_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LotArea      1460 non-null   int64
#  1   OverallQual  1460 non-null   int64
#  2   OverallCond  1460 non-null   int64
#  3   YearBuilt    1460 non-null   int64
#  4   TotalBsmtSF  1460 non-null   int64
#  5   1stFlrSF     1460 non-null   int64
#  6   2ndFlrSF     1460 non-null   int64
#  7   GrLivArea    1460 non-null   int64
#  8   FullBath     1460 non-null   int64
#  9   HalfBath     1460 non-null   int64
#  10  Fireplaces   1460 non-null   int64
#  11  GarageCars   1460 non-null   int64
#  12  GarageArea   1460 non-null   int64
#  13  PoolArea     1460 non-null   int64
#  14  YrSold       1460 non-null   int64
# dtypes: int64(15)
# memory usage: 171.2 KB

# %%
house_features.describe()
# Out:
#              LotArea  OverallQual  OverallCond    YearBuilt  TotalBsmtSF  \
# count    1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean    10516.828082     6.099315     5.575342  1971.267808  1057.429452
# std      9981.264932     1.382997     1.112799    30.202904   438.705324
# min      1300.000000     1.000000     1.000000  1872.000000     0.000000
# 25%      7553.500000     5.000000     5.000000  1954.000000   795.750000
# 50%      9478.500000     6.000000     5.000000  1973.000000   991.500000
# 75%     11601.500000     7.000000     6.000000  2000.000000  1298.250000
# max    215245.000000    10.000000     9.000000  2010.000000  6110.000000
#
#           1stFlrSF     2ndFlrSF    GrLivArea     FullBath     HalfBath  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000
# mean   1162.626712   346.992466  1515.463699     1.565068     0.382877
# std     386.587738   436.528436   525.480383     0.550916     0.502885
# ...

# %%
house_features.head()
# Out:
#    LotArea  OverallQual  OverallCond  YearBuilt  TotalBsmtSF  1stFlrSF  \
# 0     8450            7            5       2003          856       856
# 1     9600            6            8       1976         1262      1262
# 2    11250            7            5       2001          920       920
# 3     9550            7            5       1915          756       961
# 4    14260            8            5       2000         1145      1145
#
#    2ndFlrSF  GrLivArea  FullBath  HalfBath  Fireplaces  GarageCars  \
# 0       854       1710         2         1           0           2
# 1         0       1262         2         0           1           2
# 2       866       1786         2         1           1           2
# 3       756       1717         1         0           1           3
# 4      1053       2198         2         1           1           3
#
#    GarageArea  PoolArea  YrSold
# 0         548         0    2008
# 1         460         0    2007
# 2         608         0    2008
# ...

# %% [markdown]
# # CHECKING FEATURES NULL VALUES

# %%
house_features.isna().sum()
# Out:
# LotArea        0
# OverallQual    0
# OverallCond    0
# YearBuilt      0
# TotalBsmtSF    0
# 1stFlrSF       0
# 2ndFlrSF       0
# GrLivArea      0
# FullBath       0
# HalfBath       0
# Fireplaces     0
# GarageCars     0
# GarageArea     0
# PoolArea       0
# YrSold         0
# dtype: int64

# %%
house_features.shape
# Out:
# (1460, 15)

# %%
house_features.dropna(axis=1, how="any", inplace=True)
# Out:
# /var/folders/vs/9m6hqff97kv6hpz3sxt392sm0000gn/T/ipykernel_84022/3871671727.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_features.dropna(axis=1, how="any", inplace=True)

# %%
house_features.shape
# Out:
# (1460, 15)

# %% [markdown]
# # BUILDING MODEL (Decision Tree)

# %%
from sklearn.tree import DecisionTreeRegressor

Decision_Tree_Model = DecisionTreeRegressor(random_state=1)


# Train model using in sample data
Decision_Tree_Model.fit(house_features, target)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
target[:5]
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
print("Making predictions for the following 5 houses:")
print(house_features.head())
# Out:
# Making predictions for the following 5 houses:
#    LotArea  OverallQual  OverallCond  YearBuilt  TotalBsmtSF  1stFlrSF  \
# 0     8450            7            5       2003          856       856
# 1     9600            6            8       1976         1262      1262
# 2    11250            7            5       2001          920       920
# 3     9550            7            5       1915          756       961
# 4    14260            8            5       2000         1145      1145
#
#    2ndFlrSF  GrLivArea  FullBath  HalfBath  Fireplaces  GarageCars  \
# 0       854       1710         2         1           0           2
# 1         0       1262         2         0           1           2
# 2       866       1786         2         1           1           2
# 3       756       1717         1         0           1           3
# 4      1053       2198         2         1           1           3
#
#    GarageArea  PoolArea  YrSold
# 0         548         0    2008
# ...

# %%
DTM_in_sample_predictions = Decision_Tree_Model.predict(house_features)
print("The Decision Tree Model predictions from in sample data are:")
print(DTM_in_sample_predictions[:5])
# Out:
# The Decision Tree Model predictions from in sample data are:
# [208500. 181500. 223500. 140000. 250000.]

# %%
print(target.head())
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ## DECISION TREE MODEL VALIDATION

# %% [markdown]
# ### Calculate Mean Absolute Error

# %%
from sklearn.metrics import mean_absolute_error

predicted_home_price = Decision_Tree_Model.predict(house_features)
# print("The mean absolute error for the in-sample data:",mean_absolute_error(target, predicted_home_price))
print("The MEA Decision Tree Model for the in-sample data:",mean_absolute_error(target, DTM_in_sample_predictions))
# Out:
# The MEA Decision Tree Model for the in-sample data: 21.334246575342465

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# Split data into training and validation data, for both features and target.
# The split is based on a random number generator. Supplying a numeric value
# to the 'random_state' argument guarantees we get the same split everytime
# we run this script.

train_house_features, val_house_features, train_target, val_target = train_test_split(house_features, target, random_state=1)

# %% [markdown]
# ### Building Decision Tree Model with Training Data

# %%
# Define model
Decision_Tree_Model = DecisionTreeRegressor()

# Fit model
Decision_Tree_Model.fit(train_house_features, train_target)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Decision Tree Predictions With Validation Data

# %%
# get predicted prices on validation data
val_predictions = Decision_Tree_Model.predict(val_house_features)

# Print the top few validation predictions
print(val_predictions[:5])

# Print the top few actual prices from validation data
print(val_target[:5])
# Out:
# [196500. 135000. 114500.  80500. 142000.]
# 258     231500
# 267     179500
# 288     122000
# 649      84500
# 1233    142000
# Name: SalePrice, dtype: int64

# %% [markdown]
# ### Calculate Decision Tree MEA in Validation Data

# %%
val_mae = mean_absolute_error(val_target, val_predictions)

print("The mean absolute error for the out-of-sample data:", val_mae)
# Out:
# The mean absolute error for the out-of-sample data: 26284.32328767123

# %% [markdown]
# ## OVERFITTING & UNDERFITTING

# %% [markdown]
# ### Compare Different Tree Size

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = DecisionTreeRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    print("MAE:",mae)
    return mae

# %%
mae_dict = {}
for max_leaf_nodes in range(2,5001):
    my_mae = get_mae(max_leaf_nodes, train_house_features, val_house_features, train_target, val_target)
    mae_dict[max_leaf_nodes] = my_mae
    # print("Max leaf nodes: %d \t\t Mean Absolute Error: %d" % (max_leaf_nodes, my_mae))

best_tree_size = min(mae_dict, key=mae_dict.get)
print("The best Max Leaf Nodes is",best_tree_size,"leaves")
# Out:
# MAE: 42961.58802858844
# MAE: 36153.132029600994
# MAE: 33781.17941983633
# MAE: 31248.7895159213
# MAE: 32330.317863889923
# MAE: 30944.59382071848
# MAE: 29542.98787535294
# MAE: 28062.316819144766
# MAE: 28059.22113628881
# MAE: 27700.113381707964
# MAE: 27097.665847461394
# MAE: 26194.344538221703
# MAE: 25507.786702636007
# MAE: 26053.337473910393
# MAE: 25423.241086319744
# MAE: 24488.211990433134
# MAE: 25171.550830078584
# MAE: 24866.453534886536
# MAE: 24979.928398095846
# MAE: 24261.212323463944
# MAE: 24124.12093403146
# MAE: 24099.431078227568
# MAE: 24191.389411560896
# MAE: 24455.26740305592
# MAE: 24068.50626620392
# MAE: 24145.346221634216
# MAE: 24191.00948321282
# MAE: 24266.583573232387
# MAE: 24296.446876220016
# MAE: 24266.284273480287
# MAE: 24178.119889918642
# MAE: 24164.954948444734
# MAE: 24268.837368536057
# MAE: 24027.835391510776
# MAE: 24027.835391510776
# MAE: 24098.700945379718
# MAE: 24098.700945379718
# MAE: 24158.83416375951
# ...

# %% [markdown]
# ### Fit Model Using All Data

# %%
# Fill in argument to make optimal size & document
final_model = DecisionTreeRegressor(max_leaf_nodes=best_tree_size, random_state=0)

# Fit the final model
final_model.fit(house_features, target)
print(final_model)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=91, random_state=0)

# %% [markdown]
# # BUILDING MODEL (RANDOM FOREST)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error

# Define the model
Random_Forest_Model = RandomForestRegressor(random_state=1)

# Fit the model
Random_Forest_Model.fit(train_house_features, train_target)

# Calculate the Mean Absolute Error of the Random Forest model
# on the validation data
forest_prediction = Random_Forest_Model.predict(val_house_features)
print("The MEA of Random Forest Model:", mean_absolute_error(val_target, forest_prediction))
# Out:
# The MEA of Random Forest Model: 17304.90276973255

# %%
print(len(target), target[:5])
# Out:
# 1460 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %%
train_target[:5]
len(train_target)
# Out:
# 1095

# %%
len(val_target)
# Out:
# 365

# %% [markdown]
# ## RANDOM FOREST MODEL VALIDATION

# %% [markdown]
# ### Calculate Mean Absolute Error

# %%
mean_absolute_error(target, house_features)

# %% [markdown]
# ## Price Comparation

# %%
# Price Prediction in Random Forest Model
print("Random Forest  Validation Predictions:", forest_prediction[:5])

# Print the top few validation predictions
print("Decision Tree Validation Predictions:", val_predictions[:5])

# Print the top few actual prices from validation data
print("Validation Prices",val_target[:5])

# Print the top few actual prices from validation data
print("Actual Prices",target[:5])
# Out:
# Random Forest  Validation Predictions: [208675.98 154062.15 116941.5   78826.   148342.09]
# Decision Tree Validation Predictions: [187500. 135000. 114500.  75000. 137500.]
# Validation Prices 258     231500
# 267     179500
# 288     122000
# 649      84500
# 1233    142000
# Name: SalePrice, dtype: int64
# Actual Prices 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64

# %% [markdown]
# # RANDOM FOREST MODEL ON ACTUAL DATA

# %%
rf_model_full_data = RandomForestRegressor(random_state=1)

# Fit rf_model_full_data on all data from training data
rf_model_full_data.fit(house_features, target)
# Out:
# RandomForestRegressor(random_state=1)

# %% [markdown]
# # APPLY MODEL ON TEST DATA

# %%
test_data_path = "../Dataset/test.csv"

# read the test_data
test_data = pandas.read_csv(test_data_path)
print(test_data.head())
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
# Create test_X which comes from test_data but includes only from the columns you used for predictions
# The list of columns is stored in a variable called test_features

print(test_data.columns)
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
test_feats = ['LotArea',
 'OverallQual',
 'OverallCond',
 'YearBuilt',
 'TotalBsmtSF',
 '1stFlrSF',
 '2ndFlrSF',
 'GrLivArea',
 'FullBath',
 'HalfBath',
 'Fireplaces',
 'GarageCars',
 'GarageArea',
 'PoolArea',
 'YrSold']

test_features = test_data[test_feats]
test_features.isna().sum()
test_features.shape
# Out:
# (1459, 15)

# %%
test_features.dropna(axis=0, how="any", inplace=True)
test_features.shape
# Out:
# /var/folders/vs/9m6hqff97kv6hpz3sxt392sm0000gn/T/ipykernel_37476/1087936479.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_features.dropna(axis=0, how="any", inplace=True)
# (1457, 15)

# %% [markdown]
# # MAKE PREDICTIONS ON TEST DATA

# %%
test_predictions = rf_model_full_data.predict(test_features)
print(test_predictions[:5])
print(target[:5])
# Out:
# [129432.   154382.   170942.93 179326.   207244.24]
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# Name: SalePrice, dtype: int64
